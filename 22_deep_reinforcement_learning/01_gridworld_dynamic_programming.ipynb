# %% [markdown]
# # Gridworld Dynamic Programming

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from rl_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
values=value_iteration()
values.to_csv(OUTPUT / 'gridworld_values.csv', index=False)
values
# Out:
#         0       1       2       3
# 0 -4.6856 -4.0951 -3.4390 -2.7100
# 1 -4.0951 -3.4390 -2.7100 -1.9000
# 2 -3.4390 -2.7100 -1.9000 -1.0000
# 3 -2.7100 -1.9000 -1.0000  0.0000
