# %% [markdown]
# # Lunar Lander Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from rl_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
rewards=lunar_lander_fallback()
rewards.to_csv(OUTPUT / 'lunar_lander_reward_curve.csv', index=False)
rewards.tail()
# Out:
#      episode  cumulative_reward
# 195      195            94.7376
# 196      196            94.9322
# 197      197            97.1038
# 198      198            99.5103
# 199      199            99.9230

# %%
rewards.plot(x='episode', y='cumulative_reward', figsize=(8,4))
plt.tight_layout()
