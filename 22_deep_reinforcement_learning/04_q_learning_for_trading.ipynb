# %% [markdown]
# # Q-Learning for Trading

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from rl_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
bt=trading_q_learning()
bt.to_parquet(OUTPUT / 'q_learning_trading_backtest.parquet', index=False)
bt.tail()
# Out:
#        t  return  position  strategy_return  equity_curve
# 495  495  0.0046         0           0.0000        5.5308
# 496  496  0.0048         0           0.0000        5.5308
# 497  497  0.0127         0           0.0000        5.5308
# 498  498  0.0166         0           0.0000        5.5308
# 499  499  0.0129         0           0.0000        5.5308

# %%
bt.equity_curve.plot(figsize=(8,4), title='Q-learning trading fallback')
plt.tight_layout()
