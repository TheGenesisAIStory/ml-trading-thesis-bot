# %% [markdown]
# # Logistic Regression Macro Data
#
# Modernized for Python 3.10+ without legacy optional dependencies.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 80)
FOLDER = Path.cwd().resolve()
if str(FOLDER) not in sys.path:
    sys.path.insert(0, str(FOLDER))
from linear_model_utils import regression_data, classification_data, panel_factor_data, ols_numpy, rank_ic
OUTPUT = FOLDER.parent / 'data' / 'linear_models'
OUTPUT.mkdir(parents=True, exist_ok=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

x, y = classification_data(seed=12)
pipe = Pipeline([('scale', StandardScaler()), ('logit', LogisticRegression(max_iter=1000))])
scores = cross_val_score(pipe, x, y, cv=5, scoring='roc_auc')
summary = pd.DataFrame([{'roc_auc_mean': scores.mean(), 'roc_auc_std': scores.std()}])
summary.to_csv(OUTPUT / 'logistic_macro_summary.csv', index=False)
display(summary)
# Out:
#    roc_auc_mean  roc_auc_std
# 0      0.904437      0.01547
