# %% [markdown]
# # Vectorized Neural Signal Backtest

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from deep_learning_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
model, scored, accuracy = fit_mlp_classifier(seed=174)
backtest = vector_backtest(scored)
backtest.to_parquet(OUTPUT / 'mlp_signal_backtest.parquet', index=False)
backtest.tail()
# Out:
#       strategy_return  equity_curve
# 1081           0.0100       24.6089
# 547            0.0100       24.8549
# 1082           0.0100       25.1035
# 271            0.0100       25.3545
# 666            0.0100       25.6081

# %%
backtest.equity_curve.plot(figsize=(10, 4), title='MLP signal equity curve')
plt.tight_layout()
