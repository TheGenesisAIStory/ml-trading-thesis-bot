# %% [markdown]
# # Feedforward Neural Network

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from deep_learning_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
model, scored, accuracy = fit_mlp_classifier(seed=171)
scored.to_parquet(OUTPUT / 'feedforward_scores.parquet', index=False)
pd.Series({'accuracy': accuracy, 'iterations': model.n_iter_}).to_frame('value')
# Out:
#              value
# accuracy    0.9528
# iterations 48.0000
