# %% [markdown]
# # Optimize NN Architecture

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from deep_learning_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
search = architecture_search()
search.to_csv(OUTPUT / 'mlp_architecture_search.csv', index=False)
search
# Out:
#   hidden_layers  accuracy
# 2      (32, 16)    0.9528
# 3      (64, 32)    0.9389
# 1         (32,)    0.9000
# 0         (16,)    0.4972

# %%
sns.barplot(data=search, x='hidden_layers', y='accuracy', color='steelblue')
plt.xticks(rotation=30)
plt.tight_layout()
