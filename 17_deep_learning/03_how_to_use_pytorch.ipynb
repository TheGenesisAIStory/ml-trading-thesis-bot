# %% [markdown]
# # PyTorch Workflow Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from deep_learning_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
model, scored, accuracy = fit_mlp_classifier(seed=173, hidden=(64, 32))
pd.Series({'accuracy': accuracy, 'layers': len(model.hidden_layer_sizes)}).to_frame('value')
# Out:
#           value
# accuracy 0.9444
# layers   2.0000
