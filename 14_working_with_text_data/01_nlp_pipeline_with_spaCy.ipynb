# %% [markdown]
# # NLP Pipeline with Local Rules

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from text_data_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
text = sample_financial_corpus().iloc[0].text
tokens = nlp_pipeline(text)
tokens.to_csv(OUTPUT / 'nlp_pipeline_tokens.csv', index=False)
tokens
# Out:
#        token  count
# 0     global      1
# 1   equities      1
# 2     gained      1
# 3  inflation      1
# 4     cooled      1
# 5    central      1
# 6      banks      1
# 7   signaled      1
# 8   patience      1
