# %% [markdown]
# # News Text Classification

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from text_data_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
data = sample_financial_corpus()
model, results, report = train_news_classifier(data)
results.to_csv(OUTPUT / 'news_classification_results.csv', index=False)
print(report)
results
# Out:
#               precision    recall  f1-score   support
#
#       credit       0.00      0.00      0.00       1.0
#     earnings       0.00      0.00      0.00       1.0
#        macro       0.00      0.00      0.00       2.0
#      markets       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       5.0
#    macro avg       0.00      0.00      0.00       5.0
# weighted avg       0.00      0.00      0.00       5.0
#        label                                               text prediction
# 11    credit  Bondholders welcomed refinancing news and a st...   earnings
# 5      macro  Manufacturing surveys declined and recession r...     credit
# 10     macro  Consumer confidence weakened despite resilient...     credit
# 2   earnings  The company beat revenue expectations and repo...     credit
# 8    markets  Energy stocks surged with oil prices while def...     credit
