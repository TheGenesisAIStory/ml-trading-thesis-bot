# %% [markdown]
# # TextBlob-Style Sentiment with Local Lexicon

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from text_data_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
posts = sample_social_posts()
sentiment = pd.DataFrame([lexical_sentiment(text) for text in posts.text])
result = pd.concat([posts, sentiment], axis=1)
result.to_csv(OUTPUT / 'lexical_sentiment.csv', index=False)
result
# Out:
#   sentiment                                               text  positive_hits  \
# 0   bullish  Strong breakout today, volume confirms the ral...              2
# 1   bearish  Weak chart, downgrade risk and demand falling ...              0
# 2   bullish  Record cash flow and margin improvement, buyer...              1
# 3   bearish  Lawsuit headline plus missed earnings, I expec...              0
# 4   bullish     Inflation cooling should support growth stocks              1
# 5   bearish      Credit stress rising and liquidity looks poor              0
#
#    negative_hits   score     label
# 0              0  0.2222  positive
# 1              3 -0.3333  negative
# 2              0  0.1429  positive
# 3              2 -0.2500  negative
# 4              0  0.1667  positive
# 5              0  0.0000   neutral
