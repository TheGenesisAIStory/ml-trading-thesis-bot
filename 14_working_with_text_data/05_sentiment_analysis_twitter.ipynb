# %% [markdown]
# # Social Sentiment Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from text_data_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
posts = sample_social_posts()
model, results, accuracy = train_sentiment_classifier(posts)
results.to_csv(OUTPUT / 'social_sentiment_results.csv', index=False)
pd.Series({'accuracy': accuracy, 'rows': len(results)}).to_frame('value')
# Out:
#           value
# accuracy 0.3333
# rows     3.0000
