# %% [markdown]
# # pLSA via NMF

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from topic_modeling_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
docs = financial_documents()
model, vectorizer, doc_topics = fit_nmf(docs.text, n_topics=4)
terms = top_terms(model, vectorizer)
terms.to_csv(OUTPUT / 'nmf_top_terms.csv', index=False)
assign_dominant_topic(doc_topics, docs)
# Out:
#          label                                               text  \
# 0     earnings  Revenue growth accelerated as cloud demand imp...
# 1     earnings  Management discussed pricing power, cost disci...
# 2       credit  Credit spreads tightened after refinancing red...
# 3       credit  Bond investors focused on leverage, liquidity,...
# 4        macro  Inflation cooled while labor markets remained ...
# 5        macro  Yield curves steepened as investors repriced g...
# 6       energy  Oil prices rose after supply cuts and stronger...
# 7       energy  Utilities highlighted renewable investment, gr...
# 8   technology  Semiconductor orders recovered as AI infrastru...
# 9   technology  Software companies emphasized retention, subsc...
# 10    consumer  Retail traffic weakened as households traded d...
# 11    consumer  Luxury sales improved in Europe while China de...
#
#    dominant_topic  topic_confidence
# 0         topic_0            0.5611
# ...
