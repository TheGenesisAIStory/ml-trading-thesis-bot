# %% [markdown]
# # Dirichlet Distribution

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from topic_modeling_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
draws = dirichlet_samples([0.5, 0.5, 0.5, 0.5], samples=1000)
draws.to_csv(OUTPUT / 'dirichlet_samples.csv', index=False)
draws.describe().T
# Out:
#              count   mean    std    min    25%    50%    75%    max
# topic_0 1,000.0000 0.2361 0.2442 0.0000 0.0337 0.1467 0.3777 0.9567
# topic_1 1,000.0000 0.2518 0.2495 0.0000 0.0471 0.1641 0.3950 0.9842
# topic_2 1,000.0000 0.2509 0.2502 0.0000 0.0383 0.1636 0.4028 0.9804
# topic_3 1,000.0000 0.2612 0.2597 0.0000 0.0458 0.1639 0.4308 0.9740

# %%
draws.plot(kind='density', figsize=(9, 4), title='Dirichlet topic probability draws')
plt.tight_layout()
