# %% [markdown]
# # Latent Semantic Indexing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from topic_modeling_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
docs = financial_documents()
model, vectorizer, doc_topics = fit_lsi(docs.text, n_topics=4)
terms = top_terms(model, vectorizer)
terms.to_csv(OUTPUT / 'lsi_top_terms.csv', index=False)
doc_topics.to_csv(OUTPUT / 'lsi_doc_topics.csv', index=False)
terms.head(12)
# Out:
#     topic  rank       term  weight
# 0       0     1     demand  0.4064
# 1       0     2     growth  0.3167
# 2       0     3   improved  0.2883
# 3       0     4    revenue  0.1765
# 4       0     5  operating  0.1765
# 5       0     6      cloud  0.1765
# 6       0     7    margins  0.1765
# 7       0     8   expanded  0.1765
# 8       1     1  investors  0.2705
# 9       1     2       risk  0.2290
# 10      1     3       bond  0.1639
# 11      1     4    focused  0.1639
