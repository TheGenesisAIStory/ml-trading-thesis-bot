# %% [markdown]
# # LDA Portable Gensim Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from topic_modeling_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
docs = financial_documents()
model, vectorizer, doc_topics, X = fit_lda(docs.text, n_topics=4)
summary = top_terms(model, vectorizer).groupby('topic')['term'].apply(lambda s: ', '.join(s.head(6))).to_frame('top_terms')
summary.to_csv(OUTPUT / 'lda_gensim_fallback_summary.csv')
summary
# Out:
#                                                top_terms
# topic
# 0      demand, growth, improved, revenue, operating, ...
# 1      investors, remained, growth, resilient, market...
# 2             demand, risk, spreads, term, reduced, near
# 3      cost, increased, stronger, utilities, reliabil...
