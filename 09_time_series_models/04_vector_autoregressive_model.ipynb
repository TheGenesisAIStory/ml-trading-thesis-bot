# %% [markdown]
# # Vector Autoregressive Model
#
# Modernized local version without fragile time-series dependencies.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 80)
FOLDER = Path.cwd().resolve()
if str(FOLDER) not in sys.path:
    sys.path.insert(0, str(FOLDER))
from time_series_utils import make_time_series, make_pair_series, stationarity_summary, fit_ar, ewma_volatility, fit_var_two, hedge_ratio, pairs_backtest
OUTPUT = FOLDER.parent / 'data' / 'time_series_models'
OUTPUT.mkdir(parents=True, exist_ok=True)
ts = make_time_series()
pair = make_pair_series()

# %%
multi = ts[['stationary_ar','random_walk']].pct_change().dropna()
coef = fit_var_two(multi, lags=2)
coef.to_csv(OUTPUT / 'var_coefficients.csv')
display(coef)
# Out:
#                     stationary_ar  random_walk
# intercept                     NaN          NaN
# stationary_ar_lag1            NaN          NaN
# stationary_ar_lag2            NaN          NaN
# random_walk_lag1              NaN          NaN
# random_walk_lag2              NaN          NaN
