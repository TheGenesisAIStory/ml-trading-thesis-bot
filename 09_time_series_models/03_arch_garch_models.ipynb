# %% [markdown]
# # Volatility Forecasts
#
# Modernized local version without fragile time-series dependencies.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 80)
FOLDER = Path.cwd().resolve()
if str(FOLDER) not in sys.path:
    sys.path.insert(0, str(FOLDER))
from time_series_utils import make_time_series, make_pair_series, stationarity_summary, fit_ar, ewma_volatility, fit_var_two, hedge_ratio, pairs_backtest
OUTPUT = FOLDER.parent / 'data' / 'time_series_models'
OUTPUT.mkdir(parents=True, exist_ok=True)
ts = make_time_series()
pair = make_pair_series()

# %%
returns = ts['random_walk'].pct_change().dropna()
vol = ewma_volatility(returns, span=30)
vol_frame = pd.DataFrame({'return': returns, 'ewma_volatility': vol}).dropna()
vol_frame.to_parquet(OUTPUT / 'ewma_volatility.parquet')
display(vol_frame.tail())
display(vol_frame.describe().T)
# Out:
#        return  ewma_volatility
# 995 -0.010374         0.008087
# 996  0.006533         0.007996
# 997 -0.001629         0.007745
# 998  0.000025         0.007491
# 999  0.003241         0.007292
#                  count      mean       std       min       25%       50%  \
# return           999.0  0.000174  0.008589 -0.027606 -0.005631  0.000297
# ewma_volatility  999.0  0.008499  0.001492  0.005353  0.007441  0.008201
#
#                       75%       max
# return           0.005660  0.027746
# ewma_volatility  0.009487  0.012782
