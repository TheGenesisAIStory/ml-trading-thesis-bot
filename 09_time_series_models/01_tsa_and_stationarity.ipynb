# %% [markdown]
# # TSA and Stationarity
#
# Modernized local version without fragile time-series dependencies.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 80)
FOLDER = Path.cwd().resolve()
if str(FOLDER) not in sys.path:
    sys.path.insert(0, str(FOLDER))
from time_series_utils import make_time_series, make_pair_series, stationarity_summary, fit_ar, ewma_volatility, fit_var_two, hedge_ratio, pairs_backtest
OUTPUT = FOLDER.parent / 'data' / 'time_series_models'
OUTPUT.mkdir(parents=True, exist_ok=True)
ts = make_time_series()
pair = make_pair_series()

# %%
summary = pd.DataFrame({col: stationarity_summary(ts[col]) for col in ['stationary_ar','random_walk','trend']}).T
summary.to_csv(OUTPUT / 'stationarity_summary.csv')
display(summary)
display(ts.tail())
# Out:
#                      mean        std  lag1_autocorr  diff_std_ratio
# stationary_ar    0.445268   0.029777       0.931627        0.367112
# random_walk    120.181443  11.162659       0.995869        0.090874
# trend           53.997020   2.361124       0.954279        0.302018
#           date  stationary_ar  random_walk      trend
# 995 2023-10-26       0.447017   114.134883  57.838231
# 996 2023-10-27       0.432016   114.880541  57.972101
# 997 2023-10-30       0.456277   114.693384  58.742443
# 998 2023-10-31       0.451011   114.696260  58.686414
# 999 2023-11-01       0.452486   115.067938  58.281483
