# %% [markdown]
# # Cointegration Diagnostics
#
# Modernized local version without fragile time-series dependencies.

# %%
from pathlib import Path
import sys
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 80)
FOLDER = Path.cwd().resolve()
if str(FOLDER) not in sys.path:
    sys.path.insert(0, str(FOLDER))
from time_series_utils import make_time_series, make_pair_series, stationarity_summary, fit_ar, ewma_volatility, fit_var_two, hedge_ratio, pairs_backtest
OUTPUT = FOLDER.parent / 'data' / 'time_series_models'
OUTPUT.mkdir(parents=True, exist_ok=True)
ts = make_time_series()
pair = make_pair_series()

# %%
beta = hedge_ratio(pair['asset_x'], pair['asset_y'])
spread = pair['asset_y'] - beta * pair['asset_x']
summary = pd.DataFrame([{'hedge_ratio': beta, 'spread_mean': spread.mean(), 'spread_std': spread.std(), 'spread_lag1_autocorr': spread.autocorr(1)}])
summary.to_csv(OUTPUT / 'cointegration_diagnostics.csv', index=False)
display(summary)
# Out:
#    hedge_ratio  spread_mean  spread_std  spread_lag1_autocorr
# 0      1.39555     5.398543    1.021773              0.033931
