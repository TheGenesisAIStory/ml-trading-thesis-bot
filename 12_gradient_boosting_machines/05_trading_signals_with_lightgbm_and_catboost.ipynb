# %% [markdown]
# # Trading Signals with Portable Gradient Boosting

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from boosting_utils import (
    FEATURES, baseline_models, ensure_output_dir, fit_best_classifier, fit_regressor,
    long_short_backtest, make_boosting_panel, make_intraday_features, model_interpretation,
    score_quantiles, tune_gbm
)

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
panel = make_boosting_panel(seed=125)
model, scored, metrics = fit_best_classifier(panel)
scored.to_parquet(OUTPUT / 'boosting_scores.parquet', index=False)
metrics.to_csv(OUTPUT / 'boosting_signal_metrics.csv', index=False)
metrics
# Out:
#      metric  value
# 0  accuracy 0.4832
# 1   roc_auc 0.4991
