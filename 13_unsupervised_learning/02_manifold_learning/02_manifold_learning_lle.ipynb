# %% [markdown]
# # Locally Linear Embedding

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for parent in [Path.cwd(), *Path.cwd().parents]:
    if (parent / 'unsupervised_utils.py').exists():
        sys.path.insert(0, str(parent))
        break

from unsupervised_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, color = swiss_roll_embedding(samples=400, seed=137)
emb = lle_embedding(X, n_neighbors=14)
emb.to_csv(OUTPUT / 'lle_embedding.csv', index=False)
emb.head()
# Out:
#      dim1    dim2
# 0  0.0474  0.0464
# 1 -0.0061 -0.0210
# 2 -0.0217  0.0726
# 3 -0.0407 -0.0452
# 4 -0.0134 -0.0027

# %%
sns.scatterplot(data=emb, x='dim1', y='dim2', hue=color, palette='viridis', legend=False)
plt.tight_layout()
