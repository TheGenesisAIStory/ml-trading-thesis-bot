# %% [markdown]
# # Manifold Asset Prices

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for parent in [Path.cwd(), *Path.cwd().parents]:
    if (parent / 'unsupervised_utils.py').exists():
        sys.path.insert(0, str(parent))
        break

from unsupervised_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
returns = make_asset_returns(seed=139).T
emb = tsne_embedding(returns, perplexity=20)
emb['asset'] = returns.index
emb.to_csv(OUTPUT / 'asset_tsne_embedding.csv', index=False)
emb.head()
# Out:
#      dim1    dim2      asset
# 0 -1.4230 -1.1808  Asset_000
# 1 -8.7821  1.0886  Asset_001
# 2 -5.8454 -6.4337  Asset_002
# 3 -5.0696  1.9049  Asset_003
# 4 -5.4727  2.8767  Asset_004

# %%
sns.scatterplot(data=emb, x='dim1', y='dim2', s=40)
plt.tight_layout()
