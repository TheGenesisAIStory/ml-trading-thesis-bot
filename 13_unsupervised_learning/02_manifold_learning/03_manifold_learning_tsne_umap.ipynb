# %% [markdown]
# # TSNE with UMAP Fallback

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for parent in [Path.cwd(), *Path.cwd().parents]:
    if (parent / 'unsupervised_utils.py').exists():
        sys.path.insert(0, str(parent))
        break

from unsupervised_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, labels = make_feature_matrix(samples=350, features=10, seed=138)
emb = tsne_embedding(X, perplexity=25)
emb.to_csv(OUTPUT / 'tsne_embedding.csv', index=False)
emb.head()
# Out:
#       dim1     dim2
# 0 -29.7545   1.6224
# 1 -30.9432   2.1792
# 2  -1.2930  20.6306
# 3  -5.2543 -23.6067
# 4   1.6975 -26.3350

# %%
sns.scatterplot(data=emb, x='dim1', y='dim2', hue=labels, palette='tab10', legend=False)
plt.tight_layout()
