# %% [markdown]
# # PCA Key Ideas

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for parent in [Path.cwd(), *Path.cwd().parents]:
    if (parent / 'unsupervised_utils.py').exists():
        sys.path.insert(0, str(parent))
        break

from unsupervised_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, labels = make_feature_matrix(features=4, seed=132)
pca, explained, scores = pca_summary(X, n_components=3)
explained.to_csv(OUTPUT / 'pca_key_ideas_explained.csv', index=False)
explained
# Out:
#    component  explained_variance  cumulative
# 0          1              0.6680      0.6680
# 1          2              0.2283      0.8962
# 2          3              0.0856      0.9818

# %%
fig, ax = plt.subplots(figsize=(6, 5))
sns.scatterplot(x=scores['PC1'], y=scores['PC2'], hue=labels, palette='tab10', ax=ax, legend=False)
plt.tight_layout()
