# %% [markdown]
# # Curse of Dimensionality

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for parent in [Path.cwd(), *Path.cwd().parents]:
    if (parent / 'unsupervised_utils.py').exists():
        sys.path.insert(0, str(parent))
        break

from unsupervised_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
distances = curse_of_dimensionality()
distances.to_csv(OUTPUT / 'curse_of_dimensionality.csv', index=False)
distances.tail()
# Out:
#     dimensions  mean_distance  min_distance
# 45          46         9.4871        5.9827
# 46          47         9.5739        6.5893
# 47          48         9.6507        6.3930
# 48          49         9.9222        6.9970
# 49          50         9.9417        7.0462

# %%
distances.plot(x='dimensions', y=['mean_distance', 'min_distance'], figsize=(9, 4), title='Distance growth by dimension')
plt.tight_layout()
