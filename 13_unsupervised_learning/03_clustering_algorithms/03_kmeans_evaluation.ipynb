# %% [markdown]
# # KMeans Evaluation

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for parent in [Path.cwd(), *Path.cwd().parents]:
    if (parent / 'unsupervised_utils.py').exists():
        sys.path.insert(0, str(parent))
        break

from unsupervised_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, _ = clustering_dataset(seed=142)
diag = kmeans_diagnostics(X)
diag.to_csv(OUTPUT / 'kmeans_diagnostics.csv', index=False)
diag
# Out:
#    k  inertia  silhouette
# 0  2 417.6308      0.4970
# 1  3 304.9856      0.4496
# 2  4 202.9327      0.4383
# 3  5 147.8045      0.4690
# 4  6 113.6153      0.4853
# 5  7  91.6596      0.4869
# 6  8  72.0574      0.4870

# %%
diag.plot(x='k', y=['inertia', 'silhouette'], subplots=True, figsize=(8, 5), title='KMeans diagnostics')
plt.tight_layout()
