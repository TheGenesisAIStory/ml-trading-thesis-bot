# %% [markdown]
# # Clustering Algorithms

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

for parent in [Path.cwd(), *Path.cwd().parents]:
    if (parent / 'unsupervised_utils.py').exists():
        sys.path.insert(0, str(parent))
        break

from unsupervised_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, true_labels = clustering_dataset(seed=140)
comparison = compare_clusterers(X)
comparison.to_csv(OUTPUT / 'clusterer_comparison.csv', index=False)
comparison
# Out:
#            model  clusters  silhouette
# 0         kmeans         2      0.4961
# 3            gmm         2      0.4960
# 1  agglomerative         2      0.4589
# 2         dbscan         3      0.0169
