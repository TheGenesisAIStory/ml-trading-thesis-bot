# %% [markdown]
# # Evaluating Embeddings

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from embedding_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
emb = cooccurrence_embeddings(corpus().text)
eval_df = evaluate_analogies(emb)
eval_df.to_csv(OUTPUT / 'embedding_similarity_checks.csv', index=False)
eval_df
# Out:
#       left    right  cosine_similarity
# 0   profit   growth             0.9605
# 2    cloud  revenue             0.9569
# 3  default     debt             0.6479
# 1     debt     risk             0.6375
