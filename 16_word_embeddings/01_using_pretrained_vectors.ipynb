# %% [markdown]
# # Using Local Embedding Vectors

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from embedding_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
docs = corpus()
emb = cooccurrence_embeddings(docs.text)
emb.to_csv(OUTPUT / 'local_word_embeddings.csv')
nearest_words(emb, 'revenue')
# Out:
#        word  similarity
# 12     debt      0.9931
# 9     costs      0.9880
# 7     cloud      0.9569
# 37  margins      0.9046
# 44   raised      0.8873
