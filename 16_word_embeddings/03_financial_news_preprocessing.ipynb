# %% [markdown]
# # Financial News Preprocessing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from embedding_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
docs = corpus()
tokens = pd.DataFrame({'text': docs.text, 'tokens': [' '.join(t) for t in sentence_tokens(docs.text)]})
tokens.to_csv(OUTPUT / 'financial_news_tokens.csv', index=False)
tokens
# Out:
#                                                 text  \
# 0  profit growth improved as cloud revenue and ma...
# 1  losses increased after weak demand and downgra...
# 2  cash flow strengthened and management raised g...
# 3  default concerns rose as debt costs and covena...
# 4  semiconductor orders recovered with artificial...
# 5  retail sales declined and inventory markdowns ...
# 6  credit spreads tightened after refinancing imp...
# 7  litigation risk and regulatory investigation w...
#
#                                               tokens
# 0  profit growth improved as cloud revenue and ma...
# 1  losses increased after weak demand and downgra...
# 2  cash flow strengthened and management raised g...
# 3  default concerns rose as debt costs and covena...
# 4  semiconductor orders recovered with artificial...
# 5  retail sales declined and inventory markdowns ...
# 6  credit spreads tightened after refinancing imp...
# 7  litigation risk and regulatory investigation w...
