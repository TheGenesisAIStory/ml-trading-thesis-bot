# %% [markdown]
# # SEC Word Embeddings

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from embedding_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
sec_docs = corpus().assign(text=lambda df: df.text + ' annual report revenue margin liquidity debt risk')
emb = cooccurrence_embeddings(sec_docs.text, dimensions=5)
emb.to_csv(OUTPUT / 'sec_word_embeddings.csv')
nearest_words(emb, 'debt')
# Out:
#           word  similarity
# 11    covenant      0.8944
# 25        hurt      0.8936
# 34  litigation      0.8244
# 48  regulatory      0.8207
# 15     default      0.8173
