# %% [markdown]
# # Financial News Embeddings Gensim Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from embedding_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
emb = cooccurrence_embeddings(corpus().text, dimensions=5, window=3)
nearest_words(emb, 'risk')
# Out:
#              word  similarity
# 24           hurt      0.9995
# 33     litigation      0.9890
# 16      downgrade      0.9540
# 60        weighed      0.9387
# 30  investigation      0.9377
