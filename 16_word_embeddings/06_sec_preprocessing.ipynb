# %% [markdown]
# # SEC Filing Preprocessing

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from embedding_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
sec_docs = corpus().assign(text=lambda df: df.text + ' annual report risk factors management discussion liquidity')
vectors, pipe = doc_vectors(sec_docs.text)
vectors.to_csv(OUTPUT / 'sec_doc_vectors.csv', index=False)
vectors.head()
# Out:
#    doc_dim_0  doc_dim_1  doc_dim_2  doc_dim_3  doc_dim_4
# 0     0.5482    -0.4816     0.2102     0.0628     0.2531
# 1     0.6494     0.2786     0.0896     0.1438    -0.1969
# 2     0.5531    -0.2939    -0.1160    -0.0880     0.5376
# 3     0.5236    -0.2145    -0.0798     0.6287    -0.4027
# 4     0.4581     0.6953    -0.0175     0.1682     0.3680
