# %% [markdown]
# # Financial News Embeddings TensorFlow Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from embedding_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
emb = cooccurrence_embeddings(corpus().text, dimensions=5, window=2)
emb.to_csv(OUTPUT / 'tensorflow_fallback_embeddings.csv')
emb.head()
# Out:
#             dim_0   dim_1   dim_2   dim_3   dim_4
# after      0.5886 -0.2560  1.5664 -1.1810 -0.5704
# and        3.7946 -3.3127 -0.5875 -0.0338 -0.0874
# artificial 0.0817  0.0467  0.1050 -0.7215  1.3462
# as         0.8459 -0.6357  1.2581  1.3431  0.5756
# balance    0.1362 -0.0135  1.0292  0.0272 -0.2017
