# %% [markdown]
# # Sample Selection

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from factor_library_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
prices=make_ohlcv(); panel=add_factors(prices); panel.to_parquet(OUTPUT / 'alpha_factor_panel.parquet', index=False); panel.head()
# Out:
#         date ticker    open    high     low   close   volume  return_1d  \
# 0 2024-09-05   A000 44.5050 44.6577 44.2197 44.6175  1511161     0.0003
# 1 2024-09-06   A000 44.4976 44.6880 44.3843 44.5015  1594124    -0.0026
# 2 2024-09-09   A000 44.3679 44.7918 44.0025 44.2497  1629697    -0.0057
# 3 2024-09-10   A000 44.6208 44.6353 44.3473 44.4604   331519     0.0048
# 4 2024-09-11   A000 44.2648 44.3129 44.0388 44.1956   885495    -0.0060
#
#    momentum_21  momentum_63  sma_20  sma_ratio  volatility_21   dollar_volume  \
# 0      -0.0927      -0.1222 47.1617    -0.0539         0.0145 67,424,224.2205
# 1      -0.0926      -0.1282 46.9095    -0.0513         0.0145 70,940,895.5974
# 2      -0.1069      -0.1212 46.6084    -0.0506         0.0141 72,113,611.5732
# 3      -0.1156      -0.1152 46.3591    -0.0410         0.0136 14,739,457.5991
# 4      -0.1062      -0.1170 46.1698    -0.0428         0.0134 39,134,976.0294
#
#    liquidity_rank  reversal_5  alpha_001  alpha_002  alpha_003  \
# 0          0.6750      0.0212     0.7928    -0.8836     0.0294
# 1          0.7500      0.0146     0.7163    -0.8835     0.0371
# 2          0.8000      0.0090     0.6415    -0.8686     0.0389
# 3          0.0750     -0.0111     0.3530    -0.8152     0.0783
# 4          0.4000      0.0091     0.6444    -0.7807     0.0686
#
#    forward_return_5d
# 0            -0.0075
# 1            -0.0140
# 2            -0.0042
# 3            -0.0126
# 4            -0.0001
