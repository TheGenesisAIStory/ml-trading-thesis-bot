# %% [markdown]
# # Common Alpha Factors

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from factor_library_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
panel=add_factors(make_ohlcv(seed=242)); factors=panel[['date','ticker','momentum_21','sma_ratio','volatility_21','liquidity_rank','forward_return_5d']]; factors.to_parquet(OUTPUT / 'common_alpha_factors.parquet', index=False); factors.head()
# Out:
#         date ticker  momentum_21  sma_ratio  volatility_21  liquidity_rank  \
# 0 2024-09-05   A000       0.0914     0.0460         0.0116          0.9500
# 1 2024-09-06   A000       0.1030     0.0508         0.0116          0.6750
# 2 2024-09-09   A000       0.0899     0.0347         0.0121          0.9250
# 3 2024-09-10   A000       0.1049     0.0321         0.0115          1.0000
# 4 2024-09-11   A000       0.0686     0.0193         0.0109          0.9750
#
#    forward_return_5d
# 0            -0.0096
# 1            -0.0182
# 2            -0.0148
# 3            -0.0017
# 4             0.0022
