# %% [markdown]
# # Indicator Zoo

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from factor_library_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
zoo=indicator_zoo(); zoo.to_csv(OUTPUT / 'indicator_zoo.csv', index=False); zoo
# Out:
#      category             factor                         description
# 0    momentum        momentum_21                       21-day return
# 1       trend          sma_ratio             close vs 20-day average
# 2  volatility      volatility_21          21-day realized volatility
# 3   liquidity     liquidity_rank  cross-sectional dollar-volume rank
# 4   formulaic  alpha_001/002/003    compact formulaic alpha examples
