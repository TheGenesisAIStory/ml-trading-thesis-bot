# %% [markdown]
# # Quantile Analysis Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from factor_library_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
panel=add_factors(make_ohlcv(seed=245)); q=quantile_returns(panel, factor='alpha_002'); q.to_csv(OUTPUT / 'alpha_quantile_returns.csv', index=False); q
# Out:
#    quantile   mean    std  count
# 0         1 0.0011 0.0264   3456
# 1         2 0.0020 0.0273   3456
# 2         3 0.0018 0.0272   3456
# 3         4 0.0024 0.0269   3456
# 4         5 0.0010 0.0264   3456

# %%
sns.barplot(data=q, x='quantile', y='mean', color='seagreen')
plt.tight_layout()
