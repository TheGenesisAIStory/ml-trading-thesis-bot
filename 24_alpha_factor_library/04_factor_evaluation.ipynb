# %% [markdown]
# # Factor Evaluation

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from factor_library_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
panel=add_factors(make_ohlcv(seed=244)); ic=evaluate_factors(panel); importance=model_importance(panel); ic.to_csv(OUTPUT / 'factor_ic.csv', index=False); importance.to_csv(OUTPUT / 'factor_importance.csv', index=False); ic
# Out:
#            factor      ic
# 6       alpha_001  0.0194
# 5      reversal_5  0.0194
# 1     momentum_63  0.0178
# 7       alpha_002  0.0155
# 3   volatility_21 -0.0110
# 0     momentum_21  0.0094
# 2       sma_ratio -0.0052
# 8       alpha_003 -0.0052
# 4  liquidity_rank  0.0032

# %%
sns.barplot(data=ic, x='ic', y='factor', color='steelblue')
plt.tight_layout()
