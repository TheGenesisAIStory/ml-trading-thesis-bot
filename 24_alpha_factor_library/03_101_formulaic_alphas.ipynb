# %% [markdown]
# # Formulaic Alpha Examples

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from factor_library_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
panel=add_factors(make_ohlcv(seed=243)); alphas=panel[['date','ticker','alpha_001','alpha_002','alpha_003','forward_return_5d']]; alphas.to_parquet(OUTPUT / 'formulaic_alpha_examples.parquet', index=False); alphas.head()
# Out:
#         date ticker  alpha_001  alpha_002  alpha_003  forward_return_5d
# 0 2024-09-05   A000     0.8838    -0.6330     0.0700            -0.0036
# 1 2024-09-06   A000     0.7386    -0.5910     0.1076            -0.0149
# 2 2024-09-09   A000     0.7215    -0.5771     0.1442            -0.0263
# 3 2024-09-10   A000     0.5137    -0.5613     0.1375            -0.0197
# 4 2024-09-11   A000     0.8272    -0.5587     0.1652            -0.0119
