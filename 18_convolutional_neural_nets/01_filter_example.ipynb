# %% [markdown]
# # Filter Example

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
_, _, images = digit_data()
filtered = edge_filter(images[0])
pd.DataFrame(filtered).to_csv(OUTPUT / 'edge_filter_example.csv', index=False)
fig, axes = plt.subplots(1, 2, figsize=(6, 3))
axes[0].imshow(images[0], cmap='gray'); axes[0].set_title('input')
axes[1].imshow(filtered, cmap='gray'); axes[1].set_title('edge filter')
plt.tight_layout()
