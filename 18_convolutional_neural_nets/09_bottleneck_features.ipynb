# %% [markdown]
# # Bottleneck Features

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y, _ = digit_data()
features = bottleneck_features(X, components=12)
features['digit'] = y
features.to_parquet(OUTPUT / 'digit_bottleneck_features.parquet', index=False)
features.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0    -0.0787    -1.3297     0.5914    -0.8134     0.4456     0.4650
# 1     0.4974     1.2980    -0.2775     0.9309    -0.3685     0.4054
# 2     0.4370     0.6222    -0.1849     0.7680     1.1329     0.2817
# 3    -0.9941    -0.2083    -0.6140     0.7672    -0.4353    -0.0681
# 4     1.4567    -0.2668     0.3547     0.8657     0.0224     0.1786
#
#    feature_6  feature_7  feature_8  feature_9  feature_10  feature_11  digit
# 0    -0.2033    -0.1596     0.0364    -0.2266     -0.1616      0.0970      0
# 1    -0.1329     0.2885    -0.2242     0.0672      0.3366     -0.1331      1
# 2    -0.1152     1.0259    -0.0450    -0.2660      0.0771     -0.0240      2
# 3     0.0651    -0.6858     0.2037    -0.4062      0.3167      0.1498      3
# 4     0.0450    -0.8151     0.2397    -0.8384     -0.1671     -0.1097      4
