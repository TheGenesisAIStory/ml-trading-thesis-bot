# %% [markdown]
# # Satellite Images Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y = trading_image_features(n_samples=200, seed=1811)
features = bottleneck_features(X, components=6)
features['urban_proxy'] = y
features.to_csv(OUTPUT / 'satellite_proxy_features.csv', index=False)
features.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0     1.7753    -0.9192    -2.4445     2.1183     2.5058     0.7843
# 1     1.4204     1.8463    -0.3858    -0.6630    -0.3907     2.5700
# 2     1.8416     0.2124    -0.3388     1.3750     1.3899    -0.2288
# 3    -1.7044     0.0893     1.2628     1.0191     2.0114    -0.4685
# 4    -1.4590    -0.7659    -0.6222    -0.7851    -0.8903     0.2263
#
#    urban_proxy
# 0            1
# 1            0
# 2            0
# 3            0
# 4            1
