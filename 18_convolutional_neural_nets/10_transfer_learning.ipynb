# %% [markdown]
# # Transfer Learning Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y, _ = digit_data()
features = bottleneck_features(X, components=12)
model = LogisticRegression(max_iter=500).fit(features, y)
score = model.score(features, y)
pd.Series({'in_sample_accuracy': score}).to_frame('value')
# Out:
#                     value
# in_sample_accuracy 0.9505
