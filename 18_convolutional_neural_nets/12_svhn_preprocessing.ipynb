# %% [markdown]
# # SVHN Preprocessing Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y, images = digit_data()
summary = pd.DataFrame({'label': y}).value_counts().rename('count').reset_index()
summary.to_csv(OUTPUT / 'svhn_fallback_label_counts.csv', index=False)
summary
# Out:
#    label  count
# 0      3    183
# 1      1    182
# 2      5    182
# 3      4    181
# 4      6    181
# 5      9    180
# 6      7    179
# 7      0    178
# 8      2    177
# 9      8    174
