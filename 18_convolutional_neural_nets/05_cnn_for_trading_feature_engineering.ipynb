# %% [markdown]
# # Trading Feature Engineering

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y = trading_image_features()
features = bottleneck_features(X, components=8)
features['target'] = y
features.to_parquet(OUTPUT / 'trading_image_features.parquet', index=False)
features.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0    -2.7294     2.0741    -0.9218     0.6372    -1.2456    -1.1265
# 1     0.0280     0.7061     1.5448     0.9914     1.3576     1.8251
# 2     2.3368    -0.0643     2.4224    -0.1042     2.0684    -1.0752
# 3    -0.3509     1.3177     0.2891    -0.6317     0.2550     1.1844
# 4     0.7110    -1.4913     0.1921     2.3921    -0.5641    -0.5536
#
#    feature_6  feature_7  target
# 0     1.3859     0.3401       0
# 1     1.9607    -1.4029       0
# 2    -1.9590     0.1847       0
# 3    -1.1571    -0.6857       1
# 4     1.1378    -0.5681       0
