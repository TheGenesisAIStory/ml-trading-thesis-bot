# %% [markdown]
# # Features to Image Format

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y = trading_image_features(n_samples=5)
images = X.reshape(-1, 8, 8)
pd.DataFrame(images[0]).to_csv(OUTPUT / 'sample_clustered_image.csv', index=False)
plt.imshow(images[0], cmap='vlag')
plt.title('Synthetic feature image')
plt.tight_layout()
