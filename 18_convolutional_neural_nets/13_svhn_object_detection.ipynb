# %% [markdown]
# # Object Detection Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from cnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
boxes = synthetic_object_boxes()
boxes.to_csv(OUTPUT / 'synthetic_object_boxes.csv', index=False)
boxes
# Out:
#    image_id   x   y  width  height       label
# 0         0   5   8     12      10  digit_like
# 1         1   8  11     12      10  digit_like
# 2         2  12  14     12      10  digit_like
# 3         3  16  17     12      10  digit_like
# 4         4  20  20     12      10  digit_like
# 5         5  24  23     12      10  digit_like
# 6         6  28  26     12      10  digit_like
# 7         7  32  29     12      10  digit_like
# 8         8  36  32     12      10  digit_like
# 9         9  40  36     12      10  digit_like
