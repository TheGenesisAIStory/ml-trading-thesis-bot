# %% [markdown]
# # Vectorized Backtest
#
# Modernized workflow without pandas_datareader, Backtrader, or Zipline runtime dependencies.

# %%
from pathlib import Path
import sys
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 80)
ROOT = Path.cwd().resolve()
if ROOT.name == '04_ml4t_workflow_with_zipline':
    WORKFLOW_DIR = ROOT.parent
else:
    WORKFLOW_DIR = ROOT
if str(WORKFLOW_DIR) not in sys.path:
    sys.path.insert(0, str(WORKFLOW_DIR))
from ml4t_workflow_utils import make_workflow_panel, vectorized_signal_backtest, walk_forward_ml, prediction_backtest
OUTPUT = WORKFLOW_DIR.parent / 'data' / 'ml4t_workflow'
OUTPUT.mkdir(parents=True, exist_ok=True)
panel = make_workflow_panel()

# %%
returns = vectorized_signal_backtest(panel)
returns['cumulative'] = (1 + returns['strategy_return']).cumprod()
returns.to_parquet(OUTPUT / 'vectorized_backtest_returns.parquet', index=False)
display(returns.tail())
display(returns['strategy_return'].describe().to_frame())
# Out:
#           date  strategy_return  cumulative
# 725 2023-11-14        -0.002261    0.911871
# 726 2023-11-15         0.002276    0.913947
# 727 2023-11-16        -0.000407    0.913575
# 728 2023-11-17         0.002663    0.916007
# 729 2023-11-20        -0.002201    0.913991
#        strategy_return
# count       730.000000
# mean         -0.000120
# std           0.002540
# min          -0.008262
# 25%          -0.001745
# 50%          -0.000095
# 75%           0.001581
# max           0.008616
