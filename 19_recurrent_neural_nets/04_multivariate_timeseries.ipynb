# %% [markdown]
# # Multivariate Time Series

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from rnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y_reg, y_cls = make_sequence_dataset(features=3)
summary = X.describe().T.head(10)
summary.to_csv(OUTPUT / 'multivariate_sequence_summary.csv')
summary
# Out:
#      count   mean    std     min     25%     50%    75%    max
# 0 979.0000 0.0177 0.7171 -1.2643 -0.6887  0.0352 0.6858 1.2868
# 1 979.0000 0.0171 0.7164 -1.2643 -0.6887  0.0352 0.6858 1.2868
# 2 979.0000 0.0031 0.9584 -3.8401 -0.6529 -0.0222 0.6396 3.9510
# 3 979.0000 0.0187 0.7178 -1.2643 -0.6887  0.0378 0.6867 1.2868
# 4 979.0000 0.0173 0.7168 -1.2643 -0.6887  0.0352 0.6858 1.2868
# 5 979.0000 0.0029 0.9585 -3.8401 -0.6529 -0.0222 0.6396 3.9510
# 6 979.0000 0.0196 0.7185 -1.2643 -0.6887  0.0378 0.6881 1.2868
# 7 979.0000 0.0175 0.7169 -1.2643 -0.6887  0.0352 0.6858 1.2868
# 8 979.0000 0.0039 0.9584 -3.8401 -0.6529 -0.0197 0.6396 3.9510
# 9 979.0000 0.0206 0.7193 -1.2643 -0.6887  0.0378 0.6906 1.2868
