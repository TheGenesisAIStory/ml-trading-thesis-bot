# %% [markdown]
# # Build Sequence Dataset

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from rnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y_reg, y_cls = make_sequence_dataset()
X.assign(target=y_reg, direction=y_cls).to_parquet(OUTPUT / 'sequence_dataset.parquet', index=False)
X.head()
# Out:
#        0       1       2      3       4       5      6       7       8   \
# 0 -0.0444  0.8039 -0.2464 0.1593  0.7372 -0.5294 0.1299  0.8183 -0.3093
# 1  0.1593  0.7372 -0.5294 0.1299  0.8183 -0.3093 0.0457 -0.0444 -1.5841
# 2  0.1299  0.8183 -0.3093 0.0457 -0.0444 -1.5841 0.2401  0.1593 -0.8656
# 3  0.0457 -0.0444 -1.5841 0.2401  0.1593 -0.8656 0.0249  0.1299  0.1398
# 4  0.2401  0.1593 -0.8656 0.0249  0.1299  0.1398 0.3092  0.0457  1.2267
#
#       9   ...      50     51     52      53     54     55      56     57  \
# 0 0.0457  ... -1.4117 0.5108 0.7718 -1.7115 0.6979 0.6614  0.0786 0.7269
# 1 0.2401  ... -1.7115 0.6979 0.6614  0.0786 0.7269 0.4559 -0.0330 0.6307
# 2 0.0249  ...  0.0786 0.7269 0.4559 -0.0330 0.6307 0.5108 -0.1673 0.8911
# 3 0.3092  ... -0.0330 0.6307 0.5108 -0.1673 0.8911 0.6979 -0.1974 0.7829
# 4 0.2092  ... -0.1673 0.8911 0.6979 -0.1974 0.7829 0.7269 -0.4351 0.6926
#
#       58      59
# 0 0.4559 -0.0330
# 1 0.5108 -0.1673
# 2 0.6979 -0.1974
# 3 0.7269 -0.4351
# 4 0.6307 -0.5832
#
# [5 rows x 60 columns]
