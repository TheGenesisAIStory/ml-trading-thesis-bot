# %% [markdown]
# # Pretrained Embedding Sentiment Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from rnn_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
model, results, accuracy = train_text_classifier()
results
# Out:
#       label                                      text prediction
# 5  negative  litigation pressure and liquidity stress   positive
# 1  negative            weak losses and downgrade risk   positive
# 4  positive    revenue recovered and margins expanded   positive
