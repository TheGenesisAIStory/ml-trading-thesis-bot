# %% [markdown]
# # Evaluate Synthetic Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from gan_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
real = real_returns(seed=213)
synth = synthetic_ar(real)
metrics = evaluate(real, synth)
metrics.to_csv(OUTPUT / 'synthetic_data_evaluation.csv', index=False)
metrics
# Out:
#         metric    real  synthetic  difference
# 0         mean -0.0002    -0.0004     -0.0002
# 1          std  0.0099     0.0099      0.0000
# 2         skew -0.2754     0.0068      0.2822
# 3  rmse_sorted     NaN        NaN      0.0022
