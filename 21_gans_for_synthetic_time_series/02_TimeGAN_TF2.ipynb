# %% [markdown]
# # TimeGAN AR Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from gan_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
real = real_returns(seed=212)
synth = synthetic_ar(real)
frame = pd.concat([real, synth], axis=1)
frame.to_parquet(OUTPUT / 'ar_synthetic_returns.parquet', index=False)
frame.head()
# Out:
#    real_return  synthetic_ar_return
# 0       0.0105               0.0105
# 1      -0.0090               0.0030
# 2      -0.0072               0.0074
# 3      -0.0024              -0.0058
# 4      -0.0114              -0.0094
