# %% [markdown]
# # DCGAN Synthetic Return Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from gan_utils import *
sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
real = real_returns()
synth = synthetic_bootstrap(real)
frame = pd.concat([real, synth], axis=1)
frame.to_parquet(OUTPUT / 'bootstrap_synthetic_returns.parquet', index=False)
frame.describe().T
# Out:
#                       count   mean    std     min     25%    50%    75%    max
# real_return      1,000.0000 0.0004 0.0093 -0.0380 -0.0052 0.0005 0.0062 0.0496
# synthetic_return 1,000.0000 0.0007 0.0095 -0.0380 -0.0049 0.0011 0.0063 0.0496

# %%
frame.plot(kind='density', figsize=(8,4), title='Real vs bootstrap synthetic returns')
plt.tight_layout()
