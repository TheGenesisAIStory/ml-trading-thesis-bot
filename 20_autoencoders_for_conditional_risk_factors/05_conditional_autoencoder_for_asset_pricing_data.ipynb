# %% [markdown]
# # Conditional Autoencoder Data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from autoencoder_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y = make_panel(seed=204)
pca, latent, rmse = pca_autoencoder(X, components=5)
latent = latent.assign(forward_return=y)
latent.to_parquet(OUTPUT / 'conditional_autoencoder_data.parquet', index=False)
latent.head()
# Out:
#    latent_0  latent_1  latent_2  latent_3  latent_4  forward_return
# 0   -4.7037    2.9669   -2.9279    0.0065    0.0197          0.0345
# 1    2.6445    1.4604    0.8298   -0.3611   -0.8266          0.0257
# 2    1.8016   -3.2604    3.7172   -1.3893   -0.1235         -0.0213
# 3   -4.0962    2.2439    1.7039    1.3909    0.2085          0.0099
# 4    1.8006   -0.2023   -2.9374   -0.7516    0.0114          0.0010
