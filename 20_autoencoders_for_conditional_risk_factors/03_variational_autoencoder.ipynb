# %% [markdown]
# # Variational Autoencoder Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from autoencoder_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y = make_panel(seed=202)
pca, latent, rmse = pca_autoencoder(X, components=4)
latent_sample = latent.sample(10, random_state=42)
latent_sample.to_csv(OUTPUT / 'vae_fallback_latent_sample.csv', index=False)
pd.Series({'latent_dimensions': latent.shape[1], 'reconstruction_rmse': rmse}).to_frame('value')
# Out:
#                      value
# latent_dimensions   4.0000
# reconstruction_rmse 0.1810
