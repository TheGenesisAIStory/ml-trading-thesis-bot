# %% [markdown]
# # Denoising Autoencoder Fallback

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from autoencoder_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y = make_panel(seed=201)
noisy, encoded, rmse = denoise_example(X)
encoded.to_parquet(OUTPUT / 'denoised_latent_features.parquet', index=False)
pd.Series({'noisy_pca_rmse': rmse}).to_frame('value')
# Out:
#                 value
# noisy_pca_rmse 0.2627
