# %% [markdown]
# # Build Stock Characteristic Dataset

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from autoencoder_utils import *

sns.set_theme(style='whitegrid', context='notebook')
pd.set_option('display.float_format', lambda x: f'{x:,.4f}')
OUTPUT = ensure_output_dir()

# %%
X, y = make_panel(samples=1000, features=24, seed=203)
dataset = X.assign(forward_return=y)
dataset.to_parquet(OUTPUT / 'stock_characteristic_dataset.parquet', index=False)
dataset.head()
# Out:
#    characteristic_00  characteristic_01  characteristic_02  characteristic_03  \
# 0            -0.1024             1.6412             0.5150            -0.2667
# 1             0.8802             0.2522            -1.7535            -0.7097
# 2             1.1697            -1.6296             0.3128            -1.3191
# 3             1.8828             1.2061            -0.9844            -1.9001
# 4            -2.4749             0.2177             0.8995             2.0636
#
#    characteristic_04  characteristic_05  characteristic_06  characteristic_07  \
# 0            -1.3498            -1.1064             1.1962            -0.0099
# 1            -0.4519            -0.6290             1.2950             0.0409
# 2             0.8227            -0.0141            -0.2477             0.9306
# 3            -1.3822            -2.0001             2.3539             2.1558
# 4             0.4052             1.5050            -1.8934            -2.4491
#
#    characteristic_08  characteristic_09  ...  characteristic_15  \
# 0            -1.0891            -0.4030  ...            -1.4866
# 1            -1.6254             1.1612  ...             2.1011
# 2             1.0161            -0.5809  ...             0.7865
# 3            -1.4464            -1.2368  ...            -0.7701
# 4             0.5970             1.4269  ...             0.0005
#
#    characteristic_16  characteristic_17  characteristic_18  characteristic_19  \
# 0            -0.6867            -1.1249            -1.5431            -0.0021
# 1             1.3479             2.0065            -0.8834             0.1067
# 2             1.4456             1.2886             0.6012            -1.0659
# 3             1.5989            -0.3034            -0.7358            -1.4886
# 4            -2.3504            -0.6549            -0.0202             1.6385
#
#    characteristic_20  characteristic_21  characteristic_22  characteristic_23  \
# 0             0.0616            -1.1153            -0.4141             0.3534
# 1             2.5285            -0.0449            -2.3464            -0.7325
# 2             0.1879             0.0727            -0.3845            -0.3869
# 3            -0.2660            -1.3353             0.1988             2.9036
# 4             0.4180             1.0244            -0.4211            -2.0483
#
#    forward_return
# 0          0.0316
# 1         -0.0264
# 2          0.0090
# 3         -0.0116
# 4          0.0312
#
# [5 rows x 25 columns]
